# %%
import pandas as pd
import seaborn as sns


datos = pd.read_csv('cancer.csv')
df = pd.DataFrame(datos)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df = df.iloc[:, 0:10]
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# Ventajas:
# Estandarización : escala las características de modo que la distribución se centre alrededor de 0, con una desviación estándar de 1.
#
# Normalización : reduce el rango de modo que el rango ahora esté entre 0 y 1 (o -1 a 1 si hay valores negativos).
#
# Escalador robusto : similar a la normalización, pero en su lugar utiliza el rango intercuartil, por lo que es robusto para los valores atípicos.
#
# Desventajas:
# Estandarización : no es bueno si los datos no se distribuyen normalmente (es decir, no hay distribución gaussiana).
#
# Normalización : dejarse influenciar por valores atípicos (es decir, valores extremos).
#
# Escalador robusto : no tiene en cuenta la mediana y solo se centra en las partes donde se encuentran los datos masivos

# %%
## OTRO DATAFRAME PARA PROBUEBAS
df2 = df.copy()
df2
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.563112     -2.073335             1.0        1.0
# 1      842517         M     1.929433     -0.353632             1.0        1.0
# 2    84300903         M     1.804487      0.456187             1.0        1.0
# 3    84348301         M     0.630271      0.253732             1.0        1.0
# 4    84358402         M     1.889678     -1.151816             1.0        1.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.069999      0.721473             1.0        1.0
# 565    926682         M     1.866960      2.085134             1.0        1.0
# 566    926954         M     1.365753      2.045574             1.0        1.0
# 567    927241         M     1.933693      2.336457             1.0        1.0
# 568     92751         B     0.110606      1.221792             1.0        1.0
#
# ...

# %%
df2 = df2.drop(['diagnosis'], axis=1)
# PARA TRANSFORMAR TODO EL DATASET
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
columns = df2.columns
df2[columns] = scaler.fit_transform(df2[columns])
df2
### SOLO UN PARENTESIS EN EL TRANSFROM CUANDO STANDARIZAMOS TODO EL df DE ESTA
## FORMA
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   -0.236405     1.097064     -2.073335             0.0        0.0
# 1   -0.236403     1.829821     -0.353632             0.0        0.0
# 2    0.431741     1.579888      0.456187             0.0        0.0
# 3    0.432121    -0.768909      0.253732             0.0        0.0
# 4    0.432201     1.750297     -1.151816             0.0        0.0
# ..        ...          ...           ...             ...        ...
# 564 -0.235732     2.110995      0.721473             0.0        0.0
# 565 -0.235730     1.704854      2.085134             0.0        0.0
# 566 -0.235727     0.702284      2.045574             0.0        0.0
# 567 -0.235725     1.838341      2.336457             0.0        0.0
# 568 -0.242406    -1.808401      1.221792             0.0        0.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# ...

# %%
## MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,3))
df['radius_mean'] = scaler.fit_transform(df[['radius_mean']])
df

## DOS PARENTESIS YA QUE LE ESTAMOS PASANDO LA COLUMNA CON EN 2D Y TIENE QUE
## SER EN LISTA
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.563112         10.38          122.80     1001.0
# 1      842517         M     1.929433         17.77          132.90     1326.0
# 2    84300903         M     1.804487         21.25          130.00     1203.0
# 3    84348301         M     0.630271         20.38           77.58      386.1
# 4    84358402         M     1.889678         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.069999         22.39          142.00     1479.0
# 565    926682         M     1.866960         28.25          131.20     1261.0
# 566    926954         M     1.365753         28.08          108.30      858.1
# 567    927241         M     1.933693         29.33          140.10     1265.0
# 568     92751         B     0.110606         24.54           47.92      181.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['texture_mean'] = scaler.fit_transform(df[['texture_mean']])
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.563112     -2.073335          122.80     1001.0
# 1      842517         M     1.929433     -0.353632          132.90     1326.0
# 2    84300903         M     1.804487      0.456187          130.00     1203.0
# 3    84348301         M     0.630271      0.253732           77.58      386.1
# 4    84358402         M     1.889678     -1.151816          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.069999      0.721473          142.00     1479.0
# 565    926682         M     1.866960      2.085134          131.20     1261.0
# 566    926954         M     1.365753      2.045574          108.30      858.1
# 567    927241         M     1.933693      2.336457          140.10     1265.0
# 568     92751         B     0.110606      1.221792           47.92      181.0
#
# ...

# %%
from sklearn.preprocessing import Binarizer
scaler = Binarizer(threshold=0.0)
df['area_mean'] = scaler.fit_transform(df[['area_mean']])
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.563112     -2.073335             1.0        1.0
# 1      842517         M     1.929433     -0.353632             1.0        1.0
# 2    84300903         M     1.804487      0.456187             1.0        1.0
# 3    84348301         M     0.630271      0.253732             1.0        1.0
# 4    84358402         M     1.889678     -1.151816             1.0        1.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.069999      0.721473             1.0        1.0
# 565    926682         M     1.866960      2.085134             1.0        1.0
# 566    926954         M     1.365753      2.045574             1.0        1.0
# 567    927241         M     1.933693      2.336457             1.0        1.0
# 568     92751         B     0.110606      1.221792             1.0        1.0
#
# ...

# %% [markdown]
# ##### Transformacion de la data para modificar sesgos

# %%
df2.skew()
# Out:
# id                     6.473752
# radius_mean            0.942380
# texture_mean           0.650450
# perimeter_mean         0.000000
# area_mean              0.000000
# smoothness_mean        0.456324
# compactness_mean       1.190123
# concavity_mean         1.401180
# concave points_mean    1.171180
# dtype: float64

# %%
sns.distplot(df2['concavity_mean'])

# %%
from sklearn.preprocessing import PowerTransformer
## yeo-johnson para valores negativos y positivos y box-cox para solo positivos
scaler = PowerTransformer(method='yeo-johnson', standardize=True)
df2['concavity_mean'] = scaler.fit_transform(df[['concavity_mean']])

sns.distplot(df2['concavity_mean'])
