# %%
import pandas as pd

datos=pd.read_csv("AB_NYC_2019.csv")
df=pd.DataFrame(datos)
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#OBSERVAMOS SUS ESTADISTICAS
df["price"].describe()
#PODEMOS OBSERVAR SUS LIMITES, EN ESTE CASO TOMARE VALORES ATIPICOS PARA LAS QUE ESTAN DEBAJO DEL PORCENTIL MINIMO DE 5% 
#Y VALORES QUE ESTEN POR ENCIMA DEL PORCENTIL DE 97%
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
#VAMOS A ESTUDIAR LOS VALORES ATIPICOS QUE TIENE DICHA COLUMNA PARA ESTO REALIZAMOS EL CALCULO PARA UN PORCENTIL DEL 95%
#LOS VALORES QUE SE ENCUENTREN POR ENCIMA DE ESTOS SERAN VALORES ATIPICOS
Max_cuartil=df["price"].quantile(0.97)  #NO SIEMPRE ES 95% ESTO PUEDE DEPENDER DE UNA PAUTA QUE SE DE
Max_cuartil
#GUARDAREMOS ESTE DATO EN UNA VARIABLE
# Out:
# 450.0

# %%
#AHORA HAREMOS LO MISMO CON EL MINIMO PARA CREAR EL UMBRAL
Min_cuartil=df["price"].quantile(0.05)
Min_cuartil
#YA SABEMOS QUE LO QUE SE ENCUENTRE POR DEBAJO DE ESTE ES UN VALOR ATIPICO
# Out:
# 40.0

# %%
#AHORA VAMOS A IDENFICICAR LOS VALORES QUE SON ATIPICOS DE UNA MANERA VISUAL
df[df["price"]>Max_cuartil]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 158       38663                   Luxury Brownstone in Boerum Hill     165789
# 233       60164                 Beautiful, elegant 3 bed SOHO loft     289653
# 242       61224                                  Huge Chelsea Loft     291112
# ...         ...                                                ...        ...
# 48740  36413632         Spacious 2BR in Beautiful Brooklyn Heights    6608220
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
#AL IGUAL PARA LOS ATIPICOS MENORES
df[df["price"]<Min_cuartil]
# Out:
#              id                                              name    host_id  \
# 36        11452                       Clean and Quiet in Brooklyn       7355
# 249       62452                    A SpeciaL!! Private Room in NY     303939
# 250       62461                       B NYC Staten Alternative...     303939
# 251       62787                       C Private Room By The Ferry     303939
# 256       63320                D Private Che@p Room 2 Explore NYC     303939
# ...         ...                                               ...        ...
# 48851  36455649  #7 New Hotel-Like Private Room KING bed near JFK  263504959
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044   The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                      Heaven for you(only for guy)  261338177
# 48871  36475746     A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
#
# ...

# %%
#UNA MENERA MAS CORTA DE REALIZAR EL CODIGO ES 
Min_cuartil2, Max_cuartil2 = df["price"].quantile([0.05,0.97])
Min_cuartil2, Max_cuartil2
# Out:
# (40.0, 450.0)

# %%
#AHORA VAMOS A SELECCIONAR LOS DATOS QUE SE ENCUENTRE EN ESTE UMBRAL, Y SE GUARDARAN EN UN NUEVO DATAFRAME
df2 = df[(df["price"]>Min_cuartil2) & (df["price"]<Max_cuartil2)]
df2
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...
