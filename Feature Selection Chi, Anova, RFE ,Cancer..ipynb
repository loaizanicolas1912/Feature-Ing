# %%
import pandas as pd

datos = pd.read_csv('cancer.csv')
df = pd.DataFrame(datos)
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df = pd.get_dummies(df, columns=['diagnosis'], drop_first=True)
df = df.drop(['id','Unnamed: 32'], axis=1)
df.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df = df.loc[:,['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','texture_worst','fractal_dimension_mean','compactness_worst','diagnosis_M']]
df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
correlacion = df.corr()
fig = plt.figure(figsize=(10,10))
sns.heatmap(correlacion, square=True, annot=True, cmap='viridis')
plt.show()

# %%
X = df.iloc[:,0:8]
Y = df['diagnosis_M']

from sklearn.feature_selection import SelectKBest, chi2

ChiSele = SelectKBest(chi2, k=4)
selection = ChiSele.fit(X,Y)
feature = selection.transform(X)

print(list(df.columns))
print(list(selection.scores_))
print(feature)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'texture_worst', 'fractal_dimension_mean', 'compactness_worst', 'diagnosis_M']
# [266.1049171951782, 93.89750809863386, 2011.1028637679044, 53991.655923751, 0.1498992638393818, 174.4493996057111, 7.430655358549724e-05, 19.314921984068796]
# [[  17.99  122.8  1001.     17.33]
#  [  20.57  132.9  1326.     23.41]
#  [  19.69  130.   1203.     25.53]
#  ...
#  [  16.6   108.3   858.1    34.12]
#  [  20.6   140.1  1265.     39.42]
#  [   7.76   47.92  181.     30.37]]

# %%
from sklearn.feature_selection import SelectKBest,f_classif
anovaselec = SelectKBest(f_classif, k=4)
selection = anovaselec.fit(X,Y)
feature = selection.transform(X)

print(list(df.columns))
print(list(selection.scores_))
print(feature)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'texture_worst', 'fractal_dimension_mean', 'compactness_worst', 'diagnosis_M']
# [646.9810209786473, 118.09605934497365, 697.235272476532, 573.0607465682366, 83.65112340843271, 149.59690468605072, 0.09345929488888627, 304.3410629037628]
# [[1.799e+01 1.228e+02 1.001e+03 6.656e-01]
#  [2.057e+01 1.329e+02 1.326e+03 1.866e-01]
#  [1.969e+01 1.300e+02 1.203e+03 4.245e-01]
#  ...
#  [1.660e+01 1.083e+02 8.581e+02 3.094e-01]
#  [2.060e+01 1.401e+02 1.265e+03 8.681e-01]
#  [7.760e+00 4.792e+01 1.810e+02 6.444e-02]]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='lbfgs', max_iter=1000)
selectionRFE = RFE(model, 4).fit(X,Y)
feature = selectionRFE.transform(X)
print(selectionRFE.ranking_)
print(feature)
# Out:
# [1 3 1 5 1 2 4 1]
# [[1.799e+01 1.228e+02 1.184e-01 6.656e-01]
#  [2.057e+01 1.329e+02 8.474e-02 1.866e-01]
#  [1.969e+01 1.300e+02 1.096e-01 4.245e-01]
#  ...
#  [1.660e+01 1.083e+02 8.455e-02 3.094e-01]
#  [2.060e+01 1.401e+02 1.178e-01 8.681e-01]
#  [7.760e+00 4.792e+01 5.263e-02 6.444e-02]]
